# %% [markdown]
# # Lecture 02. 딥러닝 핵심 미리보기

# %% [markdown]
# ## 나의 첫 딥러닝: '폐암 수술 환장의 생존율 예측' 코드 미리보기

# %% [markdown]
# ### 1. 환경 준비

# %%
# 텐서플로의 케라스 API에서 필요한 함수들을 불러옵니다.
# 데이터를 다루는데 필요한 라이브러리를 불러옵니다.
from tensorflow import keras
from keras import Sequential, Input
from keras.layers import Dense
import numpy as np

# %% [markdown]
# ### 2. 데이터 준비

# %%
# 준비된 수술 환자 데이터를 불러옵니다.
dataset = np.loadtxt("./data/ThoracicSurgery3.csv", delimiter=',')
x = dataset[:, 0:16]    # 환자의 진찰 기록을 변수 x에 저장합니다.
y = dataset[:, 16]      # 수술 후 사망/생존 여부를 변수 y에 저장합니다.

# %% [markdown]
# ### 3. 구조 결정

# %%
# 딥러닝 모델의 구조를 결정합니다.
model = Sequential()
model.add(Input(shape=(16,)))
model.add(Dense(30, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# %% [markdown]
# ### 4. 모델 실행

# %%
# 딥러닝 모델을 실행합니다.
model.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])
history = model.fit(x, y, epochs=5, batch_size=16)
# Out:
# Epoch 1/5
# 30/30 [==============================] - 1s 2ms/step - loss: 1.8923 - accuracy: 0.4447
# Epoch 2/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.5071 - accuracy: 0.8511
# Epoch 3/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4552 - accuracy: 0.8511
# Epoch 4/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4454 - accuracy: 0.8511
# Epoch 5/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4400 - accuracy: 0.8511
