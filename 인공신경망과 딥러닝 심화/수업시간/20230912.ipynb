# %%
# 셀(Cell)이라고 부릅니다.
#.ipynb <-- Interactive Python Notebook

print("좋은 아침입니다!")

print("반가워요! 아침식사는 하셨나요?")
# Out:
# 좋은 아침입니다!
# 반가워요! 아침식사는 하셨나요?

# %% [markdown]
# ##**Chapter 03. 구글 코랩 실행하기!**
# ###9/12(화) 수업 내용

# %%
print("학교 근처에서 식사 어디서 하시나요?")
# Out:
# 학교 근처에서 식사 어디서 하시나요?

# %%
import tensorflow as tf
# as <-- alias = ~라는 별칭으로 부르다.

print(tf.__version__)
# Out:
# 2.13.0
